# %% [markdown]
# Cargar librerias y dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("All_Pokemon.csv", index_col='Name')

# %% [markdown]
# Letra A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1034 entries, Bulbasaur to Kangaskhan
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Number                   1034 non-null   int64
#  1   Type 1                   1034 non-null   object
#  2   Type 2                   549 non-null    object
#  3   Abilities                1034 non-null   object
#  4   HP                       1034 non-null   int64
#  5   Att                      1034 non-null   int64
#  6   Def                      1034 non-null   int64
#  7   Spa                      1034 non-null   int64
#  8   Spd                      1034 non-null   int64
#  9   Spe                      1034 non-null   int64
#  10  BST                      1034 non-null   int64
#  11  Mean                     1034 non-null   float64
#  12  Standard Deviation       1034 non-null   float64
#  13  Generation               1034 non-null   float64
# ...

# %%
df.describe()
# Out:
#             Number           HP          Att          Def          Spa  \
# count  1034.000000  1034.000000  1034.000000  1034.000000  1034.000000
# mean    440.117021    69.930368    80.544487    74.590909    72.908124
# std     262.398946    26.188367    32.514268    30.885981    32.764971
# min       1.000000     1.000000     5.000000     5.000000    10.000000
# 25%     212.000000    50.000000    55.250000    50.000000    50.000000
# 50%     435.500000    67.000000    78.000000    70.000000    65.000000
# 75%     668.750000    83.000000   100.000000    90.000000    95.000000
# max     900.000000   255.000000   190.000000   230.000000   194.000000
#
#                Spd          Spe          BST         Mean  Standard Deviation  \
# count  1034.000000  1034.000000  1034.000000  1034.000000         1034.000000
# mean     72.159574    68.609284   438.742747    73.123791           20.028863
# std      27.603097    30.225102   120.577842    20.096307           10.819824
# ...

# %% [markdown]
# Letra B Encontrando Duplicados

# %%
duplicados=df[df.duplicated()]

# %% [markdown]
# letra C

# %%
df.isnull().any()
# Out:
# Number                     False
# Type 1                     False
# Type 2                      True
# Abilities                  False
# HP                         False
# Att                        False
# Def                        False
# Spa                        False
# Spd                        False
# Spe                        False
# BST                        False
# Mean                       False
# Standard Deviation         False
# Generation                 False
# Experience type            False
# Experience to level 100    False
# Final Evolution            False
# Catch Rate                 False
# Legendary                  False
# Mega Evolution             False
# Alolan Form                False
# Galarian Form              False
# Against Normal             False
# Against Fire               False
# Against Water              False
# Against Electric           False
# Against Grass              False
# Against Ice                False
# ...

# %%
filas_nulas = df[df.isnull().any(axis=1)]
filas_nulas.count()
# Out:
# Number                     485
# Type 1                     485
# Type 2                       0
# Abilities                  485
# HP                         485
# Att                        485
# Def                        485
# Spa                        485
# Spd                        485
# Spe                        485
# BST                        485
# Mean                       485
# Standard Deviation         485
# Generation                 485
# Experience type            485
# Experience to level 100    485
# Final Evolution            485
# Catch Rate                 485
# Legendary                  485
# Mega Evolution             485
# Alolan Form                485
# Galarian Form              485
# Against Normal             485
# Against Fire               485
# Against Water              485
# Against Electric           485
# Against Grass              485
# Against Ice                485
# Against Fighting           485
# Against Poison             485
# ...
